# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


target_file= os.getcwd() + "/data/popularityBias.csv"
df = pd.read_csv(target_file)
x_data = df['SharedNews']
y_data = df['deviation']
plt.scatter(x_data, y_data)
